# %%
#Importing Libraries
import pandas as pd
import numpy as np

# %%
#Reading our dataset file
data = pd.read_csv("D:/Rural Handmade/Question2/ecommerce_sample_dataset.csv")

# %%
data
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# 1      http://www.flipkart.com/fabhomedecor-fabric-do...
# 2      http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3      http://www.flipkart.com/alisha-solid-women-s-c...
# 4      http://www.flipkart.com/sicons-all-purpose-arn...
# ...                                                  ...
# 19995  http://www.flipkart.com/walldesign-small-vinyl...
# 19996  http://www.flipkart.com/wallmantra-large-vinyl...
# 19997  http://www.flipkart.com/elite-collection-mediu...
# 19998  http://www.flipkart.com/elite-collection-mediu...
# 19999  http://www.flipkart.com/elite-collection-mediu...
#
#                                   product_name  \
# 0          Alisha Solid Women's Cycling Shorts
# 1          FabHomeDecor Fabric Double Sofa Bed
# 2                                   AW Bellies
# 3          Alisha Solid Women's Cycling Shorts
# 4        Sicons All Purpose Arnica Dog Shampoo
# ...                                        ...
# 19995           WallDesign Small Vinyl Sticker
# 19996  Wallmantra Large Vinyl Stickers Sticker
# 19997  Elite Collection Medium Acrylic Sticker
# 19998  Elite Collection Medium Acrylic Sticker
# 19999  Elite Collection Medium Acrylic Sticker
#
#                                    product_category_tree               pid  \
# 0      ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2FF9KEDEFGF
# 1      ["Furniture >> Living Room Furniture >> Sofa B...  SBEEH3QGU7MFYJFY
# 2      ["Footwear >> Women's Footwear >> Ballerinas >...  SHOEH4GRSUBJGZXE
# 3      ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2F6HUZMQ6SJ
# 4      ["Pet Supplies >> Grooming >> Skin & Coat Care...  PSOEH3ZYDMSYARJ5
# ...                                                  ...               ...
# 19995  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE7KFJAKSTDY9G
# 19996  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE9F5URNQGJCGH
# 19997  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE7VAYDKQZEBSD
# 19998  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE8YSVEPPCZ42Y
# 19999  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE88KN9ZDSGZKY
#
#        retail_price  discounted_price  \
# 0             999.0             379.0
# 1           32157.0           22646.0
# 2             999.0             499.0
# 3             699.0             267.0
# 4             220.0             210.0
# ...             ...               ...
# 19995        1500.0             730.0
# 19996        1429.0            1143.0
# 19997        1299.0             999.0
# 19998        1499.0            1199.0
# 19999        1499.0             999.0
#
#                                                    image  \
# 0      ["http://img5a.flixcart.com/image/short/u/4/a/...
# 1      ["http://img6a.flixcart.com/image/sofa-bed/j/f...
# 2      ["http://img5a.flixcart.com/image/shoe/7/z/z/r...
# 3      ["http://img5a.flixcart.com/image/short/6/2/h/...
# 4      ["http://img5a.flixcart.com/image/pet-shampoo/...
# ...                                                  ...
# 19995  ["http://img6a.flixcart.com/image/wall-decorat...
# 19996  ["http://img6a.flixcart.com/image/sticker/z/g/...
# 19997  ["http://img5a.flixcart.com/image/sticker/b/s/...
# 19998  ["http://img5a.flixcart.com/image/sticker/4/2/...
# 19999  ["http://img6a.flixcart.com/image/sticker/z/k/...
#
#        is_FK_Advantage_product  \
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 19995                    False
# 19996                    False
# 19997                    False
# 19998                    False
# 19999                    False
#
#                                              description       product_rating  \
# 0      Key Features of Alisha Solid Women's Cycling S...  No rating available
# 1      FabHomeDecor Fabric Double Sofa Bed (Finish Co...  No rating available
# 2      Key Features of AW Bellies Sandals Wedges Heel...  No rating available
# 3      Key Features of Alisha Solid Women's Cycling S...  No rating available
# 4      Specifications of Sicons All Purpose Arnica Do...  No rating available
# ...                                                  ...                  ...
# 19995  Buy WallDesign Small Vinyl Sticker for Rs.730 ...  No rating available
# 19996  Buy Wallmantra Large Vinyl Stickers Sticker fo...  No rating available
# 19997  Buy Elite Collection Medium Acrylic Sticker fo...  No rating available
# 19998  Buy Elite Collection Medium Acrylic Sticker fo...  No rating available
# 19999  Buy Elite Collection Medium Acrylic Sticker fo...  No rating available
#
#             overall_rating             brand  \
# 0      No rating available            Alisha
# 1      No rating available      FabHomeDecor
# 2      No rating available                AW
# 3      No rating available            Alisha
# 4      No rating available            Sicons
# ...                    ...               ...
# 19995  No rating available        WallDesign
# 19996  No rating available        Wallmantra
# 19997  No rating available  Elite Collection
# 19998  No rating available  Elite Collection
# 19999  No rating available  Elite Collection
#
#                                   product_specifications
# 0      {"product_specification"=>[{"key"=>"Number of ...
# 1      {"product_specification"=>[{"key"=>"Installati...
# 2      {"product_specification"=>[{"key"=>"Ideal For"...
# 3      {"product_specification"=>[{"key"=>"Number of ...
# 4      {"product_specification"=>[{"key"=>"Pet Type",...
# ...                                                  ...
# 19995  {"product_specification"=>[{"key"=>"Number of ...
# 19996  {"product_specification"=>[{"key"=>"Number of ...
# 19997  {"product_specification"=>[{"key"=>"Number of ...
# 19998  {"product_specification"=>[{"key"=>"Number of ...
# 19999  {"product_specification"=>[{"key"=>"Number of ...
#
# [20000 rows x 15 columns]

# %%
#List of colums in our data
data.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %%
#Dropping non existant values from our dataset
data.dropna(subset = ["brand"],inplace = True)
data.dropna(subset = ["retail_price"] , inplace = True)
data.dropna(subset = ["discounted_price"],inplace = True)
data
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# 1      http://www.flipkart.com/fabhomedecor-fabric-do...
# 2      http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3      http://www.flipkart.com/alisha-solid-women-s-c...
# 4      http://www.flipkart.com/sicons-all-purpose-arn...
# ...                                                  ...
# 19995  http://www.flipkart.com/walldesign-small-vinyl...
# 19996  http://www.flipkart.com/wallmantra-large-vinyl...
# 19997  http://www.flipkart.com/elite-collection-mediu...
# 19998  http://www.flipkart.com/elite-collection-mediu...
# 19999  http://www.flipkart.com/elite-collection-mediu...
#
#                                   product_name  \
# 0          Alisha Solid Women's Cycling Shorts
# 1          FabHomeDecor Fabric Double Sofa Bed
# 2                                   AW Bellies
# 3          Alisha Solid Women's Cycling Shorts
# 4        Sicons All Purpose Arnica Dog Shampoo
# ...                                        ...
# 19995           WallDesign Small Vinyl Sticker
# 19996  Wallmantra Large Vinyl Stickers Sticker
# 19997  Elite Collection Medium Acrylic Sticker
# 19998  Elite Collection Medium Acrylic Sticker
# 19999  Elite Collection Medium Acrylic Sticker
#
#                                    product_category_tree               pid  \
# 0      ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2FF9KEDEFGF
# 1      ["Furniture >> Living Room Furniture >> Sofa B...  SBEEH3QGU7MFYJFY
# 2      ["Footwear >> Women's Footwear >> Ballerinas >...  SHOEH4GRSUBJGZXE
# 3      ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2F6HUZMQ6SJ
# 4      ["Pet Supplies >> Grooming >> Skin & Coat Care...  PSOEH3ZYDMSYARJ5
# ...                                                  ...               ...
# 19995  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE7KFJAKSTDY9G
# 19996  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE9F5URNQGJCGH
# 19997  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE7VAYDKQZEBSD
# 19998  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE8YSVEPPCZ42Y
# 19999  ["Baby Care >> Baby & Kids Gifts >> Stickers >...  STIE88KN9ZDSGZKY
#
#        retail_price  discounted_price  \
# 0             999.0             379.0
# 1           32157.0           22646.0
# 2             999.0             499.0
# 3             699.0             267.0
# 4             220.0             210.0
# ...             ...               ...
# 19995        1500.0             730.0
# 19996        1429.0            1143.0
# 19997        1299.0             999.0
# 19998        1499.0            1199.0
# 19999        1499.0             999.0
#
#                                                    image  \
# 0      ["http://img5a.flixcart.com/image/short/u/4/a/...
# 1      ["http://img6a.flixcart.com/image/sofa-bed/j/f...
# 2      ["http://img5a.flixcart.com/image/shoe/7/z/z/r...
# 3      ["http://img5a.flixcart.com/image/short/6/2/h/...
# 4      ["http://img5a.flixcart.com/image/pet-shampoo/...
# ...                                                  ...
# 19995  ["http://img6a.flixcart.com/image/wall-decorat...
# 19996  ["http://img6a.flixcart.com/image/sticker/z/g/...
# 19997  ["http://img5a.flixcart.com/image/sticker/b/s/...
# 19998  ["http://img5a.flixcart.com/image/sticker/4/2/...
# 19999  ["http://img6a.flixcart.com/image/sticker/z/k/...
#
#        is_FK_Advantage_product  \
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 19995                    False
# 19996                    False
# 19997                    False
# 19998                    False
# 19999                    False
#
#                                              description       product_rating  \
# 0      Key Features of Alisha Solid Women's Cycling S...  No rating available
# 1      FabHomeDecor Fabric Double Sofa Bed (Finish Co...  No rating available
# 2      Key Features of AW Bellies Sandals Wedges Heel...  No rating available
# 3      Key Features of Alisha Solid Women's Cycling S...  No rating available
# 4      Specifications of Sicons All Purpose Arnica Do...  No rating available
# ...                                                  ...                  ...
# 19995  Buy WallDesign Small Vinyl Sticker for Rs.730 ...  No rating available
# 19996  Buy Wallmantra Large Vinyl Stickers Sticker fo...  No rating available
# 19997  Buy Elite Collection Medium Acrylic Sticker fo...  No rating available
# 19998  Buy Elite Collection Medium Acrylic Sticker fo...  No rating available
# 19999  Buy Elite Collection Medium Acrylic Sticker fo...  No rating available
#
#             overall_rating             brand  \
# 0      No rating available            Alisha
# 1      No rating available      FabHomeDecor
# 2      No rating available                AW
# 3      No rating available            Alisha
# 4      No rating available            Sicons
# ...                    ...               ...
# 19995  No rating available        WallDesign
# 19996  No rating available        Wallmantra
# 19997  No rating available  Elite Collection
# 19998  No rating available  Elite Collection
# 19999  No rating available  Elite Collection
#
#                                   product_specifications
# 0      {"product_specification"=>[{"key"=>"Number of ...
# 1      {"product_specification"=>[{"key"=>"Installati...
# 2      {"product_specification"=>[{"key"=>"Ideal For"...
# 3      {"product_specification"=>[{"key"=>"Number of ...
# 4      {"product_specification"=>[{"key"=>"Pet Type",...
# ...                                                  ...
# 19995  {"product_specification"=>[{"key"=>"Number of ...
# 19996  {"product_specification"=>[{"key"=>"Number of ...
# 19997  {"product_specification"=>[{"key"=>"Number of ...
# 19998  {"product_specification"=>[{"key"=>"Number of ...
# 19999  {"product_specification"=>[{"key"=>"Number of ...
#
# [14071 rows x 15 columns]

# %%
#Deleting colums which are not useful for analysis and recommender system pipeline.
data = data.drop(['uniq_id','product_url', 'pid',
       'image', 'is_FK_Advantage_product', 'product_rating',
       'overall_rating'],axis = 1)
data
# Out:
#                  crawl_timestamp                             product_name  \
# 0      2016-03-25 22:59:23 +0000      Alisha Solid Women's Cycling Shorts
# 1      2016-03-25 22:59:23 +0000      FabHomeDecor Fabric Double Sofa Bed
# 2      2016-03-25 22:59:23 +0000                               AW Bellies
# 3      2016-03-25 22:59:23 +0000      Alisha Solid Women's Cycling Shorts
# 4      2016-03-25 22:59:23 +0000    Sicons All Purpose Arnica Dog Shampoo
# ...                          ...                                      ...
# 19995  2015-12-01 10:15:43 +0000           WallDesign Small Vinyl Sticker
# 19996  2015-12-01 10:15:43 +0000  Wallmantra Large Vinyl Stickers Sticker
# 19997  2015-12-01 10:15:43 +0000  Elite Collection Medium Acrylic Sticker
# 19998  2015-12-01 10:15:43 +0000  Elite Collection Medium Acrylic Sticker
# 19999  2015-12-01 10:15:43 +0000  Elite Collection Medium Acrylic Sticker
#
#                                    product_category_tree  retail_price  \
# 0      ["Clothing >> Women's Clothing >> Lingerie, Sl...         999.0
# 1      ["Furniture >> Living Room Furniture >> Sofa B...       32157.0
# 2      ["Footwear >> Women's Footwear >> Ballerinas >...         999.0
# 3      ["Clothing >> Women's Clothing >> Lingerie, Sl...         699.0
# 4      ["Pet Supplies >> Grooming >> Skin & Coat Care...         220.0
# ...                                                  ...           ...
# 19995  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1500.0
# 19996  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1429.0
# 19997  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1299.0
# 19998  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1499.0
# 19999  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1499.0
#
#        discounted_price                                        description  \
# 0                 379.0  Key Features of Alisha Solid Women's Cycling S...
# 1               22646.0  FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2                 499.0  Key Features of AW Bellies Sandals Wedges Heel...
# 3                 267.0  Key Features of Alisha Solid Women's Cycling S...
# 4                 210.0  Specifications of Sicons All Purpose Arnica Do...
# ...                 ...                                                ...
# 19995             730.0  Buy WallDesign Small Vinyl Sticker for Rs.730 ...
# 19996            1143.0  Buy Wallmantra Large Vinyl Stickers Sticker fo...
# 19997             999.0  Buy Elite Collection Medium Acrylic Sticker fo...
# 19998            1199.0  Buy Elite Collection Medium Acrylic Sticker fo...
# 19999             999.0  Buy Elite Collection Medium Acrylic Sticker fo...
#
#                   brand                             product_specifications
# 0                Alisha  {"product_specification"=>[{"key"=>"Number of ...
# 1          FabHomeDecor  {"product_specification"=>[{"key"=>"Installati...
# 2                    AW  {"product_specification"=>[{"key"=>"Ideal For"...
# 3                Alisha  {"product_specification"=>[{"key"=>"Number of ...
# 4                Sicons  {"product_specification"=>[{"key"=>"Pet Type",...
# ...                 ...                                                ...
# 19995        WallDesign  {"product_specification"=>[{"key"=>"Number of ...
# 19996        Wallmantra  {"product_specification"=>[{"key"=>"Number of ...
# 19997  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
# 19998  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
# 19999  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
#
# [14071 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14071 entries, 0 to 19999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   crawl_timestamp         14071 non-null  object
#  1   product_name            14071 non-null  object
#  2   product_category_tree   14071 non-null  object
#  3   retail_price            14071 non-null  float64
#  4   discounted_price        14071 non-null  float64
#  5   description             14070 non-null  object
#  6   brand                   14071 non-null  object
#  7   product_specifications  14059 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 989.4+ KB

# %%
#Usimg product category tree to get the primary,secondary and tertiary category of the product
data['Category_of_Product'] = data['product_category_tree'].apply(lambda x: x.split('>>')[0][2:])

# %%
data
# Out:
#                  crawl_timestamp                             product_name  \
# 0      2016-03-25 22:59:23 +0000      Alisha Solid Women's Cycling Shorts
# 1      2016-03-25 22:59:23 +0000      FabHomeDecor Fabric Double Sofa Bed
# 2      2016-03-25 22:59:23 +0000                               AW Bellies
# 3      2016-03-25 22:59:23 +0000      Alisha Solid Women's Cycling Shorts
# 4      2016-03-25 22:59:23 +0000    Sicons All Purpose Arnica Dog Shampoo
# ...                          ...                                      ...
# 19995  2015-12-01 10:15:43 +0000           WallDesign Small Vinyl Sticker
# 19996  2015-12-01 10:15:43 +0000  Wallmantra Large Vinyl Stickers Sticker
# 19997  2015-12-01 10:15:43 +0000  Elite Collection Medium Acrylic Sticker
# 19998  2015-12-01 10:15:43 +0000  Elite Collection Medium Acrylic Sticker
# 19999  2015-12-01 10:15:43 +0000  Elite Collection Medium Acrylic Sticker
#
#                                    product_category_tree  retail_price  \
# 0      ["Clothing >> Women's Clothing >> Lingerie, Sl...         999.0
# 1      ["Furniture >> Living Room Furniture >> Sofa B...       32157.0
# 2      ["Footwear >> Women's Footwear >> Ballerinas >...         999.0
# 3      ["Clothing >> Women's Clothing >> Lingerie, Sl...         699.0
# 4      ["Pet Supplies >> Grooming >> Skin & Coat Care...         220.0
# ...                                                  ...           ...
# 19995  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1500.0
# 19996  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1429.0
# 19997  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1299.0
# 19998  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1499.0
# 19999  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1499.0
#
#        discounted_price                                        description  \
# 0                 379.0  Key Features of Alisha Solid Women's Cycling S...
# 1               22646.0  FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2                 499.0  Key Features of AW Bellies Sandals Wedges Heel...
# 3                 267.0  Key Features of Alisha Solid Women's Cycling S...
# 4                 210.0  Specifications of Sicons All Purpose Arnica Do...
# ...                 ...                                                ...
# 19995             730.0  Buy WallDesign Small Vinyl Sticker for Rs.730 ...
# 19996            1143.0  Buy Wallmantra Large Vinyl Stickers Sticker fo...
# 19997             999.0  Buy Elite Collection Medium Acrylic Sticker fo...
# 19998            1199.0  Buy Elite Collection Medium Acrylic Sticker fo...
# 19999             999.0  Buy Elite Collection Medium Acrylic Sticker fo...
#
#                   brand                             product_specifications  \
# 0                Alisha  {"product_specification"=>[{"key"=>"Number of ...
# 1          FabHomeDecor  {"product_specification"=>[{"key"=>"Installati...
# 2                    AW  {"product_specification"=>[{"key"=>"Ideal For"...
# 3                Alisha  {"product_specification"=>[{"key"=>"Number of ...
# 4                Sicons  {"product_specification"=>[{"key"=>"Pet Type",...
# ...                 ...                                                ...
# 19995        WallDesign  {"product_specification"=>[{"key"=>"Number of ...
# 19996        Wallmantra  {"product_specification"=>[{"key"=>"Number of ...
# 19997  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
# 19998  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
# 19999  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
#
#       Category_of_Product
# 0               Clothing
# 1              Furniture
# 2               Footwear
# 3               Clothing
# 4           Pet Supplies
# ...                   ...
# 19995          Baby Care
# 19996          Baby Care
# 19997          Baby Care
# 19998          Baby Care
# 19999          Baby Care
#
# [14071 rows x 9 columns]

# %%
#Defining the lambda functions to get the categories of the product. Try function is used to prevent errors if the some categories do not exist.
def secondary(x):
    try:
        return x.split('>>')[1][1:]
    except IndexError:
        return 'None '
    
def tertiary(x):
    try:
        return x.split('>>')[2][1:]
    except IndexError:
        return 'None '
    
def quaternary(x):
    try:
        return x.split('>>')[3][1:]
    except IndexError:
        return 'None '

# %%
data['SecondaryCategory'] = data['product_category_tree'].apply(secondary)
data['TertiaryCategory'] = data['product_category_tree'].apply(tertiary)
data['QuaternaryCategory'] = data['product_category_tree'].apply(quaternary)

# %%
data
# Out:
#                  crawl_timestamp                             product_name  \
# 0      2016-03-25 22:59:23 +0000      Alisha Solid Women's Cycling Shorts
# 1      2016-03-25 22:59:23 +0000      FabHomeDecor Fabric Double Sofa Bed
# 2      2016-03-25 22:59:23 +0000                               AW Bellies
# 3      2016-03-25 22:59:23 +0000      Alisha Solid Women's Cycling Shorts
# 4      2016-03-25 22:59:23 +0000    Sicons All Purpose Arnica Dog Shampoo
# ...                          ...                                      ...
# 19995  2015-12-01 10:15:43 +0000           WallDesign Small Vinyl Sticker
# 19996  2015-12-01 10:15:43 +0000  Wallmantra Large Vinyl Stickers Sticker
# 19997  2015-12-01 10:15:43 +0000  Elite Collection Medium Acrylic Sticker
# 19998  2015-12-01 10:15:43 +0000  Elite Collection Medium Acrylic Sticker
# 19999  2015-12-01 10:15:43 +0000  Elite Collection Medium Acrylic Sticker
#
#                                    product_category_tree  retail_price  \
# 0      ["Clothing >> Women's Clothing >> Lingerie, Sl...         999.0
# 1      ["Furniture >> Living Room Furniture >> Sofa B...       32157.0
# 2      ["Footwear >> Women's Footwear >> Ballerinas >...         999.0
# 3      ["Clothing >> Women's Clothing >> Lingerie, Sl...         699.0
# 4      ["Pet Supplies >> Grooming >> Skin & Coat Care...         220.0
# ...                                                  ...           ...
# 19995  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1500.0
# 19996  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1429.0
# 19997  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1299.0
# 19998  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1499.0
# 19999  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1499.0
#
#        discounted_price                                        description  \
# 0                 379.0  Key Features of Alisha Solid Women's Cycling S...
# 1               22646.0  FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2                 499.0  Key Features of AW Bellies Sandals Wedges Heel...
# 3                 267.0  Key Features of Alisha Solid Women's Cycling S...
# 4                 210.0  Specifications of Sicons All Purpose Arnica Do...
# ...                 ...                                                ...
# 19995             730.0  Buy WallDesign Small Vinyl Sticker for Rs.730 ...
# 19996            1143.0  Buy Wallmantra Large Vinyl Stickers Sticker fo...
# 19997             999.0  Buy Elite Collection Medium Acrylic Sticker fo...
# 19998            1199.0  Buy Elite Collection Medium Acrylic Sticker fo...
# 19999             999.0  Buy Elite Collection Medium Acrylic Sticker fo...
#
#                   brand                             product_specifications  \
# 0                Alisha  {"product_specification"=>[{"key"=>"Number of ...
# 1          FabHomeDecor  {"product_specification"=>[{"key"=>"Installati...
# 2                    AW  {"product_specification"=>[{"key"=>"Ideal For"...
# 3                Alisha  {"product_specification"=>[{"key"=>"Number of ...
# 4                Sicons  {"product_specification"=>[{"key"=>"Pet Type",...
# ...                 ...                                                ...
# 19995        WallDesign  {"product_specification"=>[{"key"=>"Number of ...
# 19996        Wallmantra  {"product_specification"=>[{"key"=>"Number of ...
# 19997  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
# 19998  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
# 19999  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
#
#       Category_of_Product       SecondaryCategory  \
# 0               Clothing        Women's Clothing
# 1              Furniture   Living Room Furniture
# 2               Footwear        Women's Footwear
# 3               Clothing        Women's Clothing
# 4           Pet Supplies                Grooming
# ...                   ...                     ...
# 19995          Baby Care       Baby & Kids Gifts
# 19996          Baby Care       Baby & Kids Gifts
# 19997          Baby Care       Baby & Kids Gifts
# 19998          Baby Care       Baby & Kids Gifts
# 19999          Baby Care       Baby & Kids Gifts
#
#                   TertiaryCategory  \
# 0      Lingerie, Sleep & Swimwear
# 1              Sofa Beds & Futons
# 2                      Ballerinas
# 3      Lingerie, Sleep & Swimwear
# 4                Skin & Coat Care
# ...                            ...
# 19995                    Stickers
# 19996                    Stickers
# 19997                    Stickers
# 19998                    Stickers
# 19999                    Stickers
#
#                                       QuaternaryCategory
# 0                                                Shorts
# 1      FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2                                           AW Bellies"]
# 3                                                Shorts
# 4                                               Shampoo
# ...                                                  ...
# 19995                              WallDesign Stickers"]
# 19996                              Wallmantra Stickers"]
# 19997                        Elite Collection Stickers"]
# 19998                        Elite Collection Stickers"]
# 19999                        Elite Collection Stickers"]
#
# [14071 rows x 12 columns]

# %%
#Dropping the column after its information was retrieved
data = data.drop('product_category_tree',axis = 1)

# %%
data
# Out:
#                                   product_name  retail_price  \
# 0          Alisha Solid Women's Cycling Shorts         999.0
# 1          FabHomeDecor Fabric Double Sofa Bed       32157.0
# 2                                   AW Bellies         999.0
# 3          Alisha Solid Women's Cycling Shorts         699.0
# 4        Sicons All Purpose Arnica Dog Shampoo         220.0
# ...                                        ...           ...
# 19995           WallDesign Small Vinyl Sticker        1500.0
# 19996  Wallmantra Large Vinyl Stickers Sticker        1429.0
# 19997  Elite Collection Medium Acrylic Sticker        1299.0
# 19998  Elite Collection Medium Acrylic Sticker        1499.0
# 19999  Elite Collection Medium Acrylic Sticker        1499.0
#
#        discounted_price                                        description  \
# 0                 379.0  Key Features of Alisha Solid Women's Cycling S...
# 1               22646.0  FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2                 499.0  Key Features of AW Bellies Sandals Wedges Heel...
# 3                 267.0  Key Features of Alisha Solid Women's Cycling S...
# 4                 210.0  Specifications of Sicons All Purpose Arnica Do...
# ...                 ...                                                ...
# 19995             730.0  Buy WallDesign Small Vinyl Sticker for Rs.730 ...
# 19996            1143.0  Buy Wallmantra Large Vinyl Stickers Sticker fo...
# 19997             999.0  Buy Elite Collection Medium Acrylic Sticker fo...
# 19998            1199.0  Buy Elite Collection Medium Acrylic Sticker fo...
# 19999             999.0  Buy Elite Collection Medium Acrylic Sticker fo...
#
#                   brand                             product_specifications  \
# 0                Alisha  {"product_specification"=>[{"key"=>"Number of ...
# 1          FabHomeDecor  {"product_specification"=>[{"key"=>"Installati...
# 2                    AW  {"product_specification"=>[{"key"=>"Ideal For"...
# 3                Alisha  {"product_specification"=>[{"key"=>"Number of ...
# 4                Sicons  {"product_specification"=>[{"key"=>"Pet Type",...
# ...                 ...                                                ...
# 19995        WallDesign  {"product_specification"=>[{"key"=>"Number of ...
# 19996        Wallmantra  {"product_specification"=>[{"key"=>"Number of ...
# 19997  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
# 19998  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
# 19999  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
#
#       Category_of_Product       SecondaryCategory  \
# 0               Clothing        Women's Clothing
# 1              Furniture   Living Room Furniture
# 2               Footwear        Women's Footwear
# 3               Clothing        Women's Clothing
# 4           Pet Supplies                Grooming
# ...                   ...                     ...
# 19995          Baby Care       Baby & Kids Gifts
# 19996          Baby Care       Baby & Kids Gifts
# 19997          Baby Care       Baby & Kids Gifts
# 19998          Baby Care       Baby & Kids Gifts
# 19999          Baby Care       Baby & Kids Gifts
#
#                   TertiaryCategory  \
# 0      Lingerie, Sleep & Swimwear
# 1              Sofa Beds & Futons
# 2                      Ballerinas
# 3      Lingerie, Sleep & Swimwear
# 4                Skin & Coat Care
# ...                            ...
# 19995                    Stickers
# 19996                    Stickers
# 19997                    Stickers
# 19998                    Stickers
# 19999                    Stickers
#
#                                       QuaternaryCategory
# 0                                                Shorts
# 1      FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2                                           AW Bellies"]
# 3                                                Shorts
# 4                                               Shampoo
# ...                                                  ...
# 19995                              WallDesign Stickers"]
# 19996                              Wallmantra Stickers"]
# 19997                        Elite Collection Stickers"]
# 19998                        Elite Collection Stickers"]
# 19999                        Elite Collection Stickers"]
#
# [14071 rows x 10 columns]

# %%
#Converting the timestamp to understandable data time format
data['crawl_timestamp'] = pd.to_datetime(data['crawl_timestamp'])
data['crawl_year'] = data['crawl_timestamp'].apply(lambda x: x.year)
data['crawl_month'] = data['crawl_timestamp'].apply(lambda x: x.month)

# %%
data
# Out:
#                 crawl_timestamp                             product_name  \
# 0     2016-03-25 22:59:23+00:00      Alisha Solid Women's Cycling Shorts
# 1     2016-03-25 22:59:23+00:00      FabHomeDecor Fabric Double Sofa Bed
# 2     2016-03-25 22:59:23+00:00                               AW Bellies
# 3     2016-03-25 22:59:23+00:00      Alisha Solid Women's Cycling Shorts
# 4     2016-03-25 22:59:23+00:00    Sicons All Purpose Arnica Dog Shampoo
# ...                         ...                                      ...
# 19995 2015-12-01 10:15:43+00:00           WallDesign Small Vinyl Sticker
# 19996 2015-12-01 10:15:43+00:00  Wallmantra Large Vinyl Stickers Sticker
# 19997 2015-12-01 10:15:43+00:00  Elite Collection Medium Acrylic Sticker
# 19998 2015-12-01 10:15:43+00:00  Elite Collection Medium Acrylic Sticker
# 19999 2015-12-01 10:15:43+00:00  Elite Collection Medium Acrylic Sticker
#
#                                    product_category_tree  retail_price  \
# 0      ["Clothing >> Women's Clothing >> Lingerie, Sl...         999.0
# 1      ["Furniture >> Living Room Furniture >> Sofa B...       32157.0
# 2      ["Footwear >> Women's Footwear >> Ballerinas >...         999.0
# 3      ["Clothing >> Women's Clothing >> Lingerie, Sl...         699.0
# 4      ["Pet Supplies >> Grooming >> Skin & Coat Care...         220.0
# ...                                                  ...           ...
# 19995  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1500.0
# 19996  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1429.0
# 19997  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1299.0
# 19998  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1499.0
# 19999  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1499.0
#
#        discounted_price                                        description  \
# 0                 379.0  Key Features of Alisha Solid Women's Cycling S...
# 1               22646.0  FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2                 499.0  Key Features of AW Bellies Sandals Wedges Heel...
# 3                 267.0  Key Features of Alisha Solid Women's Cycling S...
# 4                 210.0  Specifications of Sicons All Purpose Arnica Do...
# ...                 ...                                                ...
# 19995             730.0  Buy WallDesign Small Vinyl Sticker for Rs.730 ...
# 19996            1143.0  Buy Wallmantra Large Vinyl Stickers Sticker fo...
# 19997             999.0  Buy Elite Collection Medium Acrylic Sticker fo...
# 19998            1199.0  Buy Elite Collection Medium Acrylic Sticker fo...
# 19999             999.0  Buy Elite Collection Medium Acrylic Sticker fo...
#
#                   brand                             product_specifications  \
# 0                Alisha  {"product_specification"=>[{"key"=>"Number of ...
# 1          FabHomeDecor  {"product_specification"=>[{"key"=>"Installati...
# 2                    AW  {"product_specification"=>[{"key"=>"Ideal For"...
# 3                Alisha  {"product_specification"=>[{"key"=>"Number of ...
# 4                Sicons  {"product_specification"=>[{"key"=>"Pet Type",...
# ...                 ...                                                ...
# 19995        WallDesign  {"product_specification"=>[{"key"=>"Number of ...
# 19996        Wallmantra  {"product_specification"=>[{"key"=>"Number of ...
# 19997  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
# 19998  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
# 19999  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
#
#       Category_of_Product       SecondaryCategory  \
# 0               Clothing        Women's Clothing
# 1              Furniture   Living Room Furniture
# 2               Footwear        Women's Footwear
# 3               Clothing        Women's Clothing
# 4           Pet Supplies                Grooming
# ...                   ...                     ...
# 19995          Baby Care       Baby & Kids Gifts
# 19996          Baby Care       Baby & Kids Gifts
# 19997          Baby Care       Baby & Kids Gifts
# 19998          Baby Care       Baby & Kids Gifts
# 19999          Baby Care       Baby & Kids Gifts
#
#                   TertiaryCategory  \
# 0      Lingerie, Sleep & Swimwear
# 1              Sofa Beds & Futons
# 2                      Ballerinas
# 3      Lingerie, Sleep & Swimwear
# 4                Skin & Coat Care
# ...                            ...
# 19995                    Stickers
# 19996                    Stickers
# 19997                    Stickers
# 19998                    Stickers
# 19999                    Stickers
#
#                                       QuaternaryCategory  crawl_year  \
# 0                                                Shorts         2016
# 1      FabHomeDecor Fabric Double Sofa Bed (Finish Co...        2016
# 2                                           AW Bellies"]        2016
# 3                                                Shorts         2016
# 4                                               Shampoo         2016
# ...                                                  ...         ...
# 19995                              WallDesign Stickers"]        2015
# 19996                              Wallmantra Stickers"]        2015
# 19997                        Elite Collection Stickers"]        2015
# 19998                        Elite Collection Stickers"]        2015
# 19999                        Elite Collection Stickers"]        2015
#
#        crawl_month
# 0                3
# 1                3
# 2                3
# 3                3
# 4                3
# ...            ...
# 19995           12
# 19996           12
# 19997           12
# 19998           12
# 19999           12
#
# [14071 rows x 14 columns]

# %%
#Dropping after useful info is retrieved
data = data.drop("crawl_timestamp", axis = 1)

# %%
data
# Out:
#                                   product_name  \
# 0          Alisha Solid Women's Cycling Shorts
# 1          FabHomeDecor Fabric Double Sofa Bed
# 2                                   AW Bellies
# 3          Alisha Solid Women's Cycling Shorts
# 4        Sicons All Purpose Arnica Dog Shampoo
# ...                                        ...
# 19995           WallDesign Small Vinyl Sticker
# 19996  Wallmantra Large Vinyl Stickers Sticker
# 19997  Elite Collection Medium Acrylic Sticker
# 19998  Elite Collection Medium Acrylic Sticker
# 19999  Elite Collection Medium Acrylic Sticker
#
#                                    product_category_tree  retail_price  \
# 0      ["Clothing >> Women's Clothing >> Lingerie, Sl...         999.0
# 1      ["Furniture >> Living Room Furniture >> Sofa B...       32157.0
# 2      ["Footwear >> Women's Footwear >> Ballerinas >...         999.0
# 3      ["Clothing >> Women's Clothing >> Lingerie, Sl...         699.0
# 4      ["Pet Supplies >> Grooming >> Skin & Coat Care...         220.0
# ...                                                  ...           ...
# 19995  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1500.0
# 19996  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1429.0
# 19997  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1299.0
# 19998  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1499.0
# 19999  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1499.0
#
#        discounted_price                                        description  \
# 0                 379.0  Key Features of Alisha Solid Women's Cycling S...
# 1               22646.0  FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2                 499.0  Key Features of AW Bellies Sandals Wedges Heel...
# 3                 267.0  Key Features of Alisha Solid Women's Cycling S...
# 4                 210.0  Specifications of Sicons All Purpose Arnica Do...
# ...                 ...                                                ...
# 19995             730.0  Buy WallDesign Small Vinyl Sticker for Rs.730 ...
# 19996            1143.0  Buy Wallmantra Large Vinyl Stickers Sticker fo...
# 19997             999.0  Buy Elite Collection Medium Acrylic Sticker fo...
# 19998            1199.0  Buy Elite Collection Medium Acrylic Sticker fo...
# 19999             999.0  Buy Elite Collection Medium Acrylic Sticker fo...
#
#                   brand                             product_specifications  \
# 0                Alisha  {"product_specification"=>[{"key"=>"Number of ...
# 1          FabHomeDecor  {"product_specification"=>[{"key"=>"Installati...
# 2                    AW  {"product_specification"=>[{"key"=>"Ideal For"...
# 3                Alisha  {"product_specification"=>[{"key"=>"Number of ...
# 4                Sicons  {"product_specification"=>[{"key"=>"Pet Type",...
# ...                 ...                                                ...
# 19995        WallDesign  {"product_specification"=>[{"key"=>"Number of ...
# 19996        Wallmantra  {"product_specification"=>[{"key"=>"Number of ...
# 19997  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
# 19998  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
# 19999  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
#
#       Category_of_Product       SecondaryCategory  \
# 0               Clothing        Women's Clothing
# 1              Furniture   Living Room Furniture
# 2               Footwear        Women's Footwear
# 3               Clothing        Women's Clothing
# 4           Pet Supplies                Grooming
# ...                   ...                     ...
# 19995          Baby Care       Baby & Kids Gifts
# 19996          Baby Care       Baby & Kids Gifts
# 19997          Baby Care       Baby & Kids Gifts
# 19998          Baby Care       Baby & Kids Gifts
# 19999          Baby Care       Baby & Kids Gifts
#
#                   TertiaryCategory  \
# 0      Lingerie, Sleep & Swimwear
# 1              Sofa Beds & Futons
# 2                      Ballerinas
# 3      Lingerie, Sleep & Swimwear
# 4                Skin & Coat Care
# ...                            ...
# 19995                    Stickers
# 19996                    Stickers
# 19997                    Stickers
# 19998                    Stickers
# 19999                    Stickers
#
#                                       QuaternaryCategory  crawl_year  \
# 0                                                Shorts         2016
# 1      FabHomeDecor Fabric Double Sofa Bed (Finish Co...        2016
# 2                                           AW Bellies"]        2016
# 3                                                Shorts         2016
# 4                                               Shampoo         2016
# ...                                                  ...         ...
# 19995                              WallDesign Stickers"]        2015
# 19996                              Wallmantra Stickers"]        2015
# 19997                        Elite Collection Stickers"]        2015
# 19998                        Elite Collection Stickers"]        2015
# 19999                        Elite Collection Stickers"]        2015
#
#        crawl_month
# 0                3
# 1                3
# 2                3
# 3                3
# 4                3
# ...            ...
# 19995           12
# 19996           12
# 19997           12
# 19998           12
# 19999           12
#
# [14071 rows x 13 columns]

# %%
#Plotting some bar graphs to get some insights over the data.

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#1. Plot of Monthly sales count.
plt.figure(figsize=(4,3))
data.groupby('crawl_month')['crawl_month'].count().plot(kind='bar')
plt.title('Sales Count by Month',fontsize=20)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.xlabel('Month',fontsize=12)
plt.ylabel('Sales Count',fontsize=12)
plt.show()
print(data.groupby('crawl_month')['crawl_month'].count())


#Monthly sales show that December is by far the most busy month for FlipKart Shopping spree.
#Oddly, Data is missing for July to November.
# Out:
# crawl_month
# 1     3201
# 2      244
# 3     1629
# 4     1133
# 5      770
# 6     1043
# 12    6051
# Name: crawl_month, dtype: int64

# %%
#2. Most sales as per Product Category

plt.figure(figsize=(12,8))
data['Category_of_Product'].value_counts()[:20].sort_values(ascending=True).plot(kind='barh')
plt.title('Category_of_Product',fontsize=20)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.show()
print('Top Ten Main Categories by Sales.\n')
print(data['Category_of_Product'].value_counts()[:10])

#Jewellery and Clothing are the most invloved sale on the flipkart market followed by Mobiles and Accessories, Automotive,Heome Decor and Furnishing.
# Out:
# Top Ten Main Categories by Sales.
#
# Jewellery                      3522
# Clothing                       3132
# Mobiles & Accessories          1097
# Automotive                     1010
# Home Decor & Festive Needs      861
# Home Furnishing                 700
# Computers                       572
# Baby Care                       455
# Tools & Hardware                387
# Footwear                        377
# Name: Category_of_Product, dtype: int64

# %%
#Delving deep into the data
plt.figure(figsize=(12,8))
data['SecondaryCategory'].value_counts()[:20].sort_values(ascending=True).plot(kind='barh')
plt.title('Secondary Category',fontsize=20)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.show()
print('Top Ten Secondary Categories by Sales.\n')
print(data['SecondaryCategory'].value_counts()[:10])

#Women's clothing and Necklaces and Chains are the most sold products.
# Out:
# Top Ten Secondary Categories by Sales.
#
# Women's Clothing                 2243
# Necklaces & Chains               1601
# Accessories & Spare parts         923
# Tablet Accessories                799
# Bangles, Bracelets & Armlets      722
# Rings"]                           709
# Men's Clothing                    541
# Tools                             399
# Kids' Clothing                    344
# Laptop Accessories                339
# Name: SecondaryCategory, dtype: int64

# %%
plt.figure(figsize=(12,8))
data['TertiaryCategory'].value_counts()[:20].sort_values(ascending=True).plot(kind='barh')
plt.title('Tertiary Category',fontsize=20)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.show()
print('Top Ten Tertiary Categories by Sales.\n')
print(data['TertiaryCategory'].value_counts()[:10])
# Out:
# Top Ten Tertiary Categories by Sales.
#
# Necklaces"]                    1562
# None                           1448
# Lingerie, Sleep & Swimwear     1178
# Cases & Covers                  794
# Western Wear                    722
# Car Interior & Exterior         675
# Bangles"]                       429
# Gardening Tools                 339
# Bracelets"]                     250
# Shirts                          217
# Name: TertiaryCategory, dtype: int64

# %%
#Most Expensive thing on the market
max_price = data['retail_price'].max()

# %%
data[data['retail_price']==max_price]

#It is actually a dual seater Sofa worth 2,50,500rs.
# Out:
#                        product_name  \
# 11631  Durian Leather 2 Seater Sofa
#
#                                    product_category_tree  retail_price  \
# 11631  ["Furniture >> Living Room >> Sofas & Sectiona...      250500.0
#
#        discounted_price                                        description  \
# 11631          162825.0  Durian Leather 2 Seater Sofa (Finish Color - B...
#
#         brand                             product_specifications  \
# 11631  Durian  {"product_specification"=>[{"value"=>"1 SOFA"}...
#
#       Category_of_Product SecondaryCategory      TertiaryCategory  \
# 11631          Furniture       Living Room   Sofas & Sectionals"]
#
#       QuaternaryCategory  crawl_year  crawl_month
# 11631              None         2015           12

# %%
#Checking the average discount percentage Product wise
data['discount_%'] = round(((data['retail_price'] - data['discounted_price']) / data['retail_price'] * 100),1) 
data[['product_name','retail_price','discounted_price','discount_%']].head()
# Out:
#                             product_name  retail_price  discounted_price  \
# 0    Alisha Solid Women's Cycling Shorts         999.0             379.0
# 1    FabHomeDecor Fabric Double Sofa Bed       32157.0           22646.0
# 2                             AW Bellies         999.0             499.0
# 3    Alisha Solid Women's Cycling Shorts         699.0             267.0
# 4  Sicons All Purpose Arnica Dog Shampoo         220.0             210.0
#
#    discount_%
# 0        62.1
# 1        29.6
# 2        50.1
# 3        61.8
# 4         4.5

# %%
ProductDiscount = pd.DataFrame(data.groupby('Category_of_Product').agg({
    'discount_%':[(np.mean)],
    'Category_of_Product':['count']
}))

ProductDiscount.columns = ['_'.join(col) for col in ProductDiscount.columns]
ProductDiscount = ProductDiscount.sort_values(by=['Category_of_Product_count'],ascending=False)[:20]

# %%
#Plotting the discount by the category of Product.
plt.figure(figsize=(12,8))
ProductDiscount['discount_%_mean'].sort_values(ascending=True).plot(kind='barh')
plt.title('Product Discount',fontsize=20)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.ylabel('Category_of_Product',fontsize=12)
plt.show()
print('Product Discount (Percentage)\n')
print(ProductDiscount['discount_%_mean'].sort_values(ascending=False)[:8])
# Out:
# Product Discount (Percentage)
#
# Category_of_Product
# Watches                   57.360417
# Automotive                54.649901
# Mobiles & Accessories     51.001185
# Clothing                  49.972158
# Bags, Wallets & Belts     49.436424
# Computers                 43.509615
# Jewellery                 40.891198
# Home Furnishing           37.218143
# Name: discount_%_mean, dtype: float64

# %%
data
# Out:
#                                   product_name  \
# 0          Alisha Solid Women's Cycling Shorts
# 1          FabHomeDecor Fabric Double Sofa Bed
# 2                                   AW Bellies
# 3          Alisha Solid Women's Cycling Shorts
# 4        Sicons All Purpose Arnica Dog Shampoo
# ...                                        ...
# 19995           WallDesign Small Vinyl Sticker
# 19996  Wallmantra Large Vinyl Stickers Sticker
# 19997  Elite Collection Medium Acrylic Sticker
# 19998  Elite Collection Medium Acrylic Sticker
# 19999  Elite Collection Medium Acrylic Sticker
#
#                                    product_category_tree  retail_price  \
# 0      ["Clothing >> Women's Clothing >> Lingerie, Sl...         999.0
# 1      ["Furniture >> Living Room Furniture >> Sofa B...       32157.0
# 2      ["Footwear >> Women's Footwear >> Ballerinas >...         999.0
# 3      ["Clothing >> Women's Clothing >> Lingerie, Sl...         699.0
# 4      ["Pet Supplies >> Grooming >> Skin & Coat Care...         220.0
# ...                                                  ...           ...
# 19995  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1500.0
# 19996  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1429.0
# 19997  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1299.0
# 19998  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1499.0
# 19999  ["Baby Care >> Baby & Kids Gifts >> Stickers >...        1499.0
#
#        discounted_price                                        description  \
# 0                 379.0  Key Features of Alisha Solid Women's Cycling S...
# 1               22646.0  FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2                 499.0  Key Features of AW Bellies Sandals Wedges Heel...
# 3                 267.0  Key Features of Alisha Solid Women's Cycling S...
# 4                 210.0  Specifications of Sicons All Purpose Arnica Do...
# ...                 ...                                                ...
# 19995             730.0  Buy WallDesign Small Vinyl Sticker for Rs.730 ...
# 19996            1143.0  Buy Wallmantra Large Vinyl Stickers Sticker fo...
# 19997             999.0  Buy Elite Collection Medium Acrylic Sticker fo...
# 19998            1199.0  Buy Elite Collection Medium Acrylic Sticker fo...
# 19999             999.0  Buy Elite Collection Medium Acrylic Sticker fo...
#
#                   brand                             product_specifications  \
# 0                Alisha  {"product_specification"=>[{"key"=>"Number of ...
# 1          FabHomeDecor  {"product_specification"=>[{"key"=>"Installati...
# 2                    AW  {"product_specification"=>[{"key"=>"Ideal For"...
# 3                Alisha  {"product_specification"=>[{"key"=>"Number of ...
# 4                Sicons  {"product_specification"=>[{"key"=>"Pet Type",...
# ...                 ...                                                ...
# 19995        WallDesign  {"product_specification"=>[{"key"=>"Number of ...
# 19996        Wallmantra  {"product_specification"=>[{"key"=>"Number of ...
# 19997  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
# 19998  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
# 19999  Elite Collection  {"product_specification"=>[{"key"=>"Number of ...
#
#       Category_of_Product       SecondaryCategory  \
# 0               Clothing        Women's Clothing
# 1              Furniture   Living Room Furniture
# 2               Footwear        Women's Footwear
# 3               Clothing        Women's Clothing
# 4           Pet Supplies                Grooming
# ...                   ...                     ...
# 19995          Baby Care       Baby & Kids Gifts
# 19996          Baby Care       Baby & Kids Gifts
# 19997          Baby Care       Baby & Kids Gifts
# 19998          Baby Care       Baby & Kids Gifts
# 19999          Baby Care       Baby & Kids Gifts
#
#                   TertiaryCategory  \
# 0      Lingerie, Sleep & Swimwear
# 1              Sofa Beds & Futons
# 2                      Ballerinas
# 3      Lingerie, Sleep & Swimwear
# 4                Skin & Coat Care
# ...                            ...
# 19995                    Stickers
# 19996                    Stickers
# 19997                    Stickers
# 19998                    Stickers
# 19999                    Stickers
#
#                                       QuaternaryCategory  crawl_year  \
# 0                                                Shorts         2016
# 1      FabHomeDecor Fabric Double Sofa Bed (Finish Co...        2016
# 2                                           AW Bellies"]        2016
# 3                                                Shorts         2016
# 4                                               Shampoo         2016
# ...                                                  ...         ...
# 19995                              WallDesign Stickers"]        2015
# 19996                              Wallmantra Stickers"]        2015
# 19997                        Elite Collection Stickers"]        2015
# 19998                        Elite Collection Stickers"]        2015
# 19999                        Elite Collection Stickers"]        2015
#
#        crawl_month  discount_%
# 0                3        62.1
# 1                3        29.6
# 2                3        50.1
# 3                3        61.8
# 4                3         4.5
# ...            ...         ...
# 19995           12        51.3
# 19996           12        20.0
# 19997           12        23.1
# 19998           12        20.0
# 19999           12        33.4
#
# [14071 rows x 14 columns]

# %%
#Saving the treated data as a new saved file for recommendation model
data.to_csv("D:/Rural Handmade/Question2/ecommerce_sample_dataset_cleaned.csv")
